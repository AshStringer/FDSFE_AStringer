# %%
import pandas as pd

# %%
videos = pd.read_csv("https://github.com/fedhere/FDSFE_FBianco/raw/main/data/USyoutubes.csv")

# %%
videos
# Out:
#       trending_date                                              title  \
# 0          17.14.11                 WE WANT TO TALK ABOUT OUR MARRIAGE
# 1          17.14.11  The Trump Presidency: Last Week Tonight with J...
# 2          17.14.11  Racist Superman | Rudy Mancuso, King Bach & Le...
# 3          17.14.11                   Nickelback Lyrics: Real or Fake?
# 4          17.14.11                           I Dare You: GOING BALD!?
# ...             ...                                                ...
# 40944      18.14.06                       The Cat Who Caught the Laser
# 40945      18.14.06                         True Facts : Ant Mutualism
# 40946      18.14.06  I GAVE SAFIYA NYGAARD A PERFECT HAIR MAKEOVER ...
# 40947      18.14.06                How Black Panther Should Have Ended
# 40948      18.14.06  Official Call of Duty®: Black Ops 4 — Multipla...
#
#                   channel_title  category_id              publish_time  \
# ...

# %%
videos.head()
# Out:
#   trending_date                                              title  \
# 0      17.14.11                 WE WANT TO TALK ABOUT OUR MARRIAGE
# 1      17.14.11  The Trump Presidency: Last Week Tonight with J...
# 2      17.14.11  Racist Superman | Rudy Mancuso, King Bach & Le...
# 3      17.14.11                   Nickelback Lyrics: Real or Fake?
# 4      17.14.11                           I Dare You: GOING BALD!?
#
#            channel_title  category_id              publish_time  \
# 0           CaseyNeistat           22  2017-11-13T17:13:01.000Z
# 1        LastWeekTonight           24  2017-11-13T07:30:00.000Z
# 2           Rudy Mancuso           23  2017-11-12T19:05:24.000Z
# 3  Good Mythical Morning           24  2017-11-13T11:00:04.000Z
# 4               nigahiga           24  2017-11-12T18:01:41.000Z
#
#                                                 tags    views   likes  \
# 0                                    SHANtell martin   748374   57527
# ...

# %%
videos.tail()
# Out:
#       trending_date                                              title  \
# 40944      18.14.06                       The Cat Who Caught the Laser
# 40945      18.14.06                         True Facts : Ant Mutualism
# 40946      18.14.06  I GAVE SAFIYA NYGAARD A PERFECT HAIR MAKEOVER ...
# 40947      18.14.06                How Black Panther Should Have Ended
# 40948      18.14.06  Official Call of Duty®: Black Ops 4 — Multipla...
#
#                   channel_title  category_id              publish_time  \
# 40944             AaronsAnimals           15  2018-05-18T13:00:04.000Z
# 40945                  zefrank1           22  2018-05-18T01:00:06.000Z
# 40946                Brad Mondo           24  2018-05-18T17:34:22.000Z
# 40947  How It Should Have Ended            1  2018-05-17T17:00:04.000Z
# 40948              Call of Duty           20  2018-05-17T17:09:38.000Z
#
#                                                     tags     views   likes  \
# ...

# %%
videos.shape
# Out:
# (40949, 10)

# %%
videos.columns
# Out:
# Index(['trending_date', 'title', 'channel_title', 'category_id',
#        'publish_time', 'tags', 'views', 'likes', 'dislikes', 'comment_count'],
#       dtype='object')

# %%
videos[['views', 'likes', 'dislikes', 'comment_count']]
# Out:
#           views   likes  dislikes  comment_count
# 0        748374   57527      2966          15954
# 1       2418783   97185      6146          12703
# 2       3191434  146033      5339           8181
# 3        343168   10172       666           2146
# 4       2095731  132235      1989          17518
# ...         ...     ...       ...            ...
# 40944   1685609   38160      1385           2657
# 40945   1064798   60008       382           3936
# 40946   1066451   48068      1032           3992
# 40947   5660813  192957      2846          13088
# 40948  10306119  357079    212976         144795
#
# [40949 rows x 4 columns]

# %%
videos_restrict = videos[['views', 'likes', 'dislikes', 'comment_count']]

# %%
videos_restrict.shape
# Out:
# (40949, 4)

# %%
videos_restrict['likes'].max()
# Out:
# 5613827

# %%
maxlikes = videos_restrict['likes'].max()

# %%
videos_restrict['likes'] == maxlikes
# Out:
# 0        False
# 1        False
# 2        False
# 3        False
# 4        False
#          ...
# 40944    False
# 40945    False
# 40946    False
# 40947    False
# 40948    False
# Name: likes, Length: 40949, dtype: bool

# %%
videos[videos['likes'] == maxlikes]
# Out:
#       trending_date                                title channel_title  \
# 38273      18.01.06  BTS (방탄소년단) 'FAKE LOVE' Official MV       ibighit
#
#        category_id              publish_time  \
# 38273           10  2018-05-18T09:00:02.000Z
#
#                                                     tags      views    likes  \
# 38273  BIGHIT|"빅히트"|"방탄소년단"|"BTS"|"BANGTAN"|"방탄"|"FAK...  123010920  5613827
#
#        dislikes  comment_count
# 38273    206892        1228655

# %%
videos_restrict['likes'].min()
# Out:
# 0

# %%
minlikes = videos_restrict['likes'].min()

# %%
videos[videos['likes'] == minlikes]
# Out:
#       trending_date                                              title  \
# 192        17.14.11                                 Apple Clips sample
# 1435       17.21.11  Breaking Bad's Bryan Cranston on Meeting Charl...
# 1490       17.21.11  Kelly Oubre Punches John Wall in the Lead duri...
# 1667       17.22.11  Breaking Bad's Bryan Cranston on Meeting Charl...
# 1741       17.22.11  Kelly Oubre Punches John Wall in the Lead duri...
# ...             ...                                                ...
# 28135      18.05.04  KKW BEAUTY: Conceal, Bake, Brighten with Mario...
# 28346      18.06.04  KKW BEAUTY: Conceal, Bake, Brighten with Mario...
# 28550      18.14.04                      Coachella 2018 LIVE Channel 1
# 28751      18.15.04                      Coachella 2018 LIVE Channel 1
# 28955      18.16.04                      Coachella 2018 LIVE Channel 1
#
#              channel_title  category_id              publish_time  \
# ...

# %%
videos[videos['likes'] == minlikes]
# Out:
#       trending_date                                              title  \
# 192        17.14.11                                 Apple Clips sample
# 1435       17.21.11  Breaking Bad's Bryan Cranston on Meeting Charl...
# 1490       17.21.11  Kelly Oubre Punches John Wall in the Lead duri...
# 1667       17.22.11  Breaking Bad's Bryan Cranston on Meeting Charl...
# 1741       17.22.11  Kelly Oubre Punches John Wall in the Lead duri...
# ...             ...                                                ...
# 28135      18.05.04  KKW BEAUTY: Conceal, Bake, Brighten with Mario...
# 28346      18.06.04  KKW BEAUTY: Conceal, Bake, Brighten with Mario...
# 28550      18.14.04                      Coachella 2018 LIVE Channel 1
# 28751      18.15.04                      Coachella 2018 LIVE Channel 1
# 28955      18.16.04                      Coachella 2018 LIVE Channel 1
#
#              channel_title  category_id              publish_time  \
# ...

# %%
videos_restrict['dislikes'].max()
# Out:
# 1674420

# %%
maxdislikes = videos_restrict['dislikes'].max()

# %%
videos_restrict['dislikes'] == maxdislikes
# Out:
# 0        False
# 1        False
# 2        False
# 3        False
# 4        False
#          ...
# 40944    False
# 40945    False
# 40946    False
# 40947    False
# 40948    False
# Name: dislikes, Length: 40949, dtype: bool

# %%
videos[videos['dislikes'] == maxdislikes]
# Out:
#       trending_date      title     channel_title  category_id  \
# 11323      18.09.01  So Sorry.  Logan Paul Vlogs           24
#
#                    publish_time  \
# 11323  2018-01-02T16:42:21.000Z
#
#                                                     tags     views    likes  \
# 11323  logan paul vlog|"logan paul"|"logan"|"paul"|"o...  37539570  1402578
#
#        dislikes  comment_count
# 11323   1674420        1361580

# %%
videos_restrict['dislikes'].min()
# Out:
# 0

# %%
mindislikes = videos_restrict['dislikes'].min()

# %%
videos_restrict['dislikes'] == mindislikes
# Out:
# 0        False
# 1        False
# 2        False
# 3        False
# 4        False
#          ...
# 40944    False
# 40945    False
# 40946    False
# 40947    False
# 40948    False
# Name: dislikes, Length: 40949, dtype: bool

# %%
videos[videos['dislikes'] == mindislikes]
# Out:
#       trending_date                                              title  \
# 147        17.14.11  Improvising in the style of different classica...
# 155        17.14.11               The Oak Beams of New College, Oxford
# 160        17.14.11             Huffy Metaloid Bicycle Commercial 1997
# 175        17.14.11                Sphaera - demonstrating interaction
# 192        17.14.11                                 Apple Clips sample
# ...             ...                                                ...
# 28135      18.05.04  KKW BEAUTY: Conceal, Bake, Brighten with Mario...
# 28346      18.06.04  KKW BEAUTY: Conceal, Bake, Brighten with Mario...
# 28550      18.14.04                      Coachella 2018 LIVE Channel 1
# 28751      18.15.04                      Coachella 2018 LIVE Channel 1
# 28955      18.16.04                      Coachella 2018 LIVE Channel 1
#
#              channel_title  category_id              publish_time  \
# ...

# %%
pd.plotting.scatter_matrix(videos_restrict);

# %%
videos_restrict['likes'].hist()
# Out:
# <Axes: >

# %%
ax = videos_restrict['likes'].hist()
ax.set_yscale('log')
ax.set_xlabel('Likes')
# Out:
# Text(0.5, 0, 'Likes')

# %%
videos_restrict.corr()
# Out:
#                   views     likes  dislikes  comment_count
# views          1.000000  0.849177  0.472213       0.617621
# likes          0.849177  1.000000  0.447186       0.803057
# dislikes       0.472213  0.447186  1.000000       0.700184
# comment_count  0.617621  0.803057  0.700184       1.000000
